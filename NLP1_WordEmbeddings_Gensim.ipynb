# %% [markdown]
# Author: Jose Camacho-Collados, Yipeng Qin
#
# This Jupyter notebook shows how to train and use word embeddings with the [Gensim](https://radimrehurek.com/gensim/) library. Some snippets have been adapted from the [Gensim's Word2Vec tutorial](https://rare-technologies.com/word2vec-tutorial/).
#
# Word embeddings are vector representations of words which are generally **low-dimensional** (often less than 1000 dimensions) vectors that encode the **semantics** of words.

# %% [markdown]
# ## TRAINING WORD EMBEDDINGS (Word2Vec)
#
# ---
#
# As usual, we first import the libraries that we are going to use, including now Gensim.
#
# **Note:** All these libraries need to be downloaded beforehand if not using Google Colab. Check their official websites for details on how to install them.

# %%
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
import gensim
import requests
import random
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\c21099797\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# To learn word embeddings, in this case Word2Vec (Mikolov et al. 2013 [link text](https://arxiv.org/pdf/1301.3781.pdf)), we first need a sufficiently large text corpus. To this end we are going to use the IMDb review corpus (the same used in Coursework 1), which includes all sentences.

# %%
url_train="http://josecamachocollados.com/imdb_train.txt" # Containing all sentences of the imdb training set

#Load training set
response_train = requests.get(url_train)
dataset_file_train = response_train.text.split("\n") # "\n" is a character representing "new line"
random.shuffle(dataset_file_train) # We shuffle all sentences of our corpus

# %% [markdown]
# Let's check what the IMDb dataset looks like

# %%
for line in dataset_file_train[:5]:
  print (line)
# Out:
# unlike others , i refuse to call this pitiful excuse for a movie a triumph of style over substance ( i do n't want to give style a bad name ) . still , it 's the most apt description that comes to mind . <br /> <br /> a pointless , unpleasant and ultimately meaningless assault on the eyes and ears , " wonderland " leaves one wondering only why the film was made in the first place and who in their right mind gave the greenlight to this dreary and tangled mess . a biography of porn star john holmes ? a study of who the man was , why he went into the business and how it affected him ? great . bound to be compelling , bound to be entertaining . bound to be enlightening and fascinating on about a million levels ( and i have zero interest in porn ) . <br /> <br /> but a confusing , violent , rashomon-style study of a series of murders holmes was connected with after his career ended ? who in hell cares ? what insights do we gain ? this film completely ignores the most interesting aspect of john holmes 's life -- that he was a porno star ! " wonderland " might as well have been about anyone : the fact that the main character is the most famous male adult film star in history is almost irrelevant . <br /> <br /> to make matters about a thousand times worse , the picture is loaded down with jerkoff gimmicks -- annoying machine gun editing , sloppy dogme-95 camerawork , unnecessary split-screen graphics and animation , etc. etc. <br /> <br /> in the absence of a compelling story and unique main character , the director ( and i use the term loosely ) has thrown together a dozen or so techniques from other films and decided to call the resulting mess a movie , among these : the trendy , bleach-bypass look of " narc " or " traffic " or " minority report ; " the frantic , often incomprehensible , throw-the-pieces-of-film-in-the-air cutting style of " natural born killers " or " 28 days later ; " the fill-every-moment-of-silence-with - an-old-song-to-evoke-the-period soundtrack of " goodfellas " or " blow ; " the groovy , retro title sequence of " velvet goldmine " or " autofocus " or " catch me if you can . " the list goes on and on and on . pathetic . <br /> <br /> i wanted to like this movie . i had real hopes for it . " wonderland avenue " had been around for years ; had the context of the murders been emphasized rather than the murders themselves , i think it could have worked . had the murders ( and holmes 's growing involvement with seedy l.a. types ) signaled the end of a career , or the end of the swinging '70s , i think the film could have had meaning ; it could have served a purpose . as it is -- meaningless . pointless . who cares how many perspectives exist on a series of murders generally unknown by the public ? the case is n't famous enough to merit such painstaking examination . <br /> <br /> this film should have been the third act of " the john holmes story . " that 's it . period . and it could have worked . what 's that ? oh , right , right , they did n't want to tell a traditional rise-and-fall story . they did n't want to make " boogie nights " or " goodfellas " or " star 80 " or " autofocus . " they wanted their film to be different . right ? <br /> <br /> well , in one sense , they succeeded . there 's a big difference between those films and " wonderland . " the difference is those films are good . <br /> <br />
# the picture is developed in 1873 and talks as lin mcadam ( james stewart ) and high spade ( millard michell ) arrive to dodge city looking for an enemy called dutch henry ( stephen mcnally ) . the sheriff wyatt hearp ( will ger ) obligates to leave their guns.both participate in an shot contest and stewart earns a winchester 73 , the rifle greatest of the west but is robbed and starting the possession hand to hand ( john mcintire , charles drake , dan duryea ) . meanwhile the starring is going on the vengeance . <br /> <br /> first western interpreted by james stewart directed by anthony mann that achieved revive the genre during 50 decade . the film has an extraordinary casting including brief apparition of rock hudson and tony curtis , both newcomers . the picture is well narrated and directed by the magnificent director anthony mann who has made abundant classics western : bend the river , far country , man of laramie , naked spur , tin star . of course , all the essential elements western are in this film , thus , red indians attack , raid by outlaws , final showdown.the breathtaking cinematography by greta garbo 's favourite photographer willian daniels . james stewart inaugurated a new type of wage , the percentage on the box office that will imitate posteriorly others great hollywood stars . although the argument is an adaptation of Â¨ big gun Â¨ novel of stuart l.lake and screenwriter is borden chase , is also based about real events because 4 july 1876 in dodge city had a shot competition and the winner was rewarded with a winchester 73 model 1873 with ability shoot 17 cartridges caliber 44/40 in few seconds .
# did you know , that anthony kiedis , ( singer from the red hot chili peppers ) father is in this movie . blackie dammit , is anthony 's father . i noticed this after reading " scar tissue " anthony 's autobiography , and saw a picture of his father . i thought , " well , that guy kinda looks like that guy from that movie i saw in the eighties . then i read more and it said his father was an actor that had a few small roles . after checking this site , and comparing with a search on the net , i realized it really is his father in the movie . it 's funny , because nowhere in the book does it mention him being in this movie . perhaps his son was ashamed of his father 's acting job in this flick , but he need not be . i think his father , blackie , did a great job in the show .
# the short that starts this film is the true footage of a guy named gary , apparently it was taken randomly in the parking lot of a television station where gary works in the town of beaver . gary is a little " different " ; he is an impersonator and drives an old chevy named farrah ( after fawcett ) . lo and behold the filmmaker gets a letter from gary some time later inviting him to return to beaver to get some footage of the local talent contest he has put together , including gary 's staggering performace as olivia newton dawn . oh , my . the two shorts that follow are gary 's story , the same one you just witnessed only the first is portrayed by sean penn and the second by crispin glover titled " the orkly kid . " if you are in the mood for making fun of someone this is definitely the film to watch . i was doubled over with laughter through most of it , especially crispins performance which could definitely stand on it 's own . when it was over , i had to rewind the film to once again watch the real gary and all his shining idiocy . although olivia was the focus , i would have liked to have seen one of the " fictitious " shorts take a jab at gary 's barry manilow impersonation , whic h was equally ridiculous .
# the film looks super on paper . a romantic comedy in which a frantic lover gets dragged into a smuggling thriller should be generic cross-breeding gold , especially with this excellent romcomic cast . <br /> <br /> i 'm afraid lawrence kasdan simply gives his two stars too much rope though and they duly go and hang themselves . adam brooks ' script may well be to blame but you 'd expect better from the kevin kline of a fish called wanda . instead the two ping-pong off one another and the unlikely burgeoning romance is never reconciled satisfactorily with the reason either of them are in and dashing around france . <br /> <br /> jean reno co-stars amiably as the cop-with-a-heart and i guess wishes he was a star-with-a-part . mind you he went on to do those pink panther remake ( s ! ) so perhaps he was ok with this ... 3/10

# %% [markdown]
# Once the dataset is loaded, we are going to tokenize and store our corpus into sentences.

# %%
gensim_imdb_corpus=[]
for line in dataset_file_train:
  gensim_imdb_corpus.append(word_tokenize(line))
# This could take a lot of memory. If it's the case you can reduce the number of lines

# %% [markdown]
# In case we do not know or we forget what "tokenize" means, we can have a quick check to see what has happened.

# %%
print ("Before tokenization:", dataset_file_train[0])
print ("After tokenization:", gensim_imdb_corpus[0])
# Out:
# Before tokenization: unlike others , i refuse to call this pitiful excuse for a movie a triumph of style over substance ( i do n't want to give style a bad name ) . still , it 's the most apt description that comes to mind . <br /> <br /> a pointless , unpleasant and ultimately meaningless assault on the eyes and ears , " wonderland " leaves one wondering only why the film was made in the first place and who in their right mind gave the greenlight to this dreary and tangled mess . a biography of porn star john holmes ? a study of who the man was , why he went into the business and how it affected him ? great . bound to be compelling , bound to be entertaining . bound to be enlightening and fascinating on about a million levels ( and i have zero interest in porn ) . <br /> <br /> but a confusing , violent , rashomon-style study of a series of murders holmes was connected with after his career ended ? who in hell cares ? what insights do we gain ? this film completely ignores the most interesting aspect of john holmes 's life -- that he was a porno star ! " wonderland " might as well have been about anyone : the fact that the main character is the most famous male adult film star in history is almost irrelevant . <br /> <br /> to make matters about a thousand times worse , the picture is loaded down with jerkoff gimmicks -- annoying machine gun editing , sloppy dogme-95 camerawork , unnecessary split-screen graphics and animation , etc. etc. <br /> <br /> in the absence of a compelling story and unique main character , the director ( and i use the term loosely ) has thrown together a dozen or so techniques from other films and decided to call the resulting mess a movie , among these : the trendy , bleach-bypass look of " narc " or " traffic " or " minority report ; " the frantic , often incomprehensible , throw-the-pieces-of-film-in-the-air cutting style of " natural born killers " or " 28 days later ; " the fill-every-moment-of-silence-with - an-old-song-to-evoke-the-period soundtrack of " goodfellas " or " blow ; " the groovy , retro title sequence of " velvet goldmine " or " autofocus " or " catch me if you can . " the list goes on and on and on . pathetic . <br /> <br /> i wanted to like this movie . i had real hopes for it . " wonderland avenue " had been around for years ; had the context of the murders been emphasized rather than the murders themselves , i think it could have worked . had the murders ( and holmes 's growing involvement with seedy l.a. types ) signaled the end of a career , or the end of the swinging '70s , i think the film could have had meaning ; it could have served a purpose . as it is -- meaningless . pointless . who cares how many perspectives exist on a series of murders generally unknown by the public ? the case is n't famous enough to merit such painstaking examination . <br /> <br /> this film should have been the third act of " the john holmes story . " that 's it . period . and it could have worked . what 's that ? oh , right , right , they did n't want to tell a traditional rise-and-fall story . they did n't want to make " boogie nights " or " goodfellas " or " star 80 " or " autofocus . " they wanted their film to be different . right ? <br /> <br /> well , in one sense , they succeeded . there 's a big difference between those films and " wonderland . " the difference is those films are good . <br /> <br />
# After tokenization: ['unlike', 'others', ',', 'i', 'refuse', 'to', 'call', 'this', 'pitiful', 'excuse', 'for', 'a', 'movie', 'a', 'triumph', 'of', 'style', 'over', 'substance', '(', 'i', 'do', "n't", 'want', 'to', 'give', 'style', 'a', 'bad', 'name', ')', '.', 'still', ',', 'it', "'s", 'the', 'most', 'apt', 'description', 'that', 'comes', 'to', 'mind', '.', '<', 'br', '/', '>', '<', 'br', '/', '>', 'a', 'pointless', ',', 'unpleasant', 'and', 'ultimately', 'meaningless', 'assault', 'on', 'the', 'eyes', 'and', 'ears', ',', '``', 'wonderland', '``', 'leaves', 'one', 'wondering', 'only', 'why', 'the', 'film', 'was', 'made', 'in', 'the', 'first', 'place', 'and', 'who', 'in', 'their', 'right', 'mind', 'gave', 'the', 'greenlight', 'to', 'this', 'dreary', 'and', 'tangled', 'mess', '.', 'a', 'biography', 'of', 'porn', 'star', 'john', 'holmes', '?', 'a', 'study', 'of', 'who', 'the', 'man', 'was', ',', 'why', 'he', 'went', 'into', 'the', 'business', 'and', 'how', 'it', 'affected', 'him', '?', 'great', '.', 'bound', 'to', 'be', 'compelling', ',', 'bound', 'to', 'be', 'entertaining', '.', 'bound', 'to', 'be', 'enlightening', 'and', 'fascinating', 'on', 'about', 'a', 'million', 'levels', '(', 'and', 'i', 'have', 'zero', 'interest', 'in', 'porn', ')', '.', '<', 'br', '/', '>', '<', 'br', '/', '>', 'but', 'a', 'confusing', ',', 'violent', ',', 'rashomon-style', 'study', 'of', 'a', 'series', 'of', 'murders', 'holmes', 'was', 'connected', 'with', 'after', 'his', 'career', 'ended', '?', 'who', 'in', 'hell', 'cares', '?', 'what', 'insights', 'do', 'we', 'gain', '?', 'this', 'film', 'completely', 'ignores', 'the', 'most', 'interesting', 'aspect', 'of', 'john', 'holmes', "'s", 'life', '--', 'that', 'he', 'was', 'a', 'porno', 'star', '!', '``', 'wonderland', '``', 'might', 'as', 'well', 'have', 'been', 'about', 'anyone', ':', 'the', 'fact', 'that', 'the', 'main', 'character', 'is', 'the', 'most', 'famous', 'male', 'adult', 'film', 'star', 'in', 'history', 'is', 'almost', 'irrelevant', '.', '<', 'br', '/', '>', '<', 'br', '/', '>', 'to', 'make', 'matters', 'about', 'a', 'thousand', 'times', 'worse', ',', 'the', 'picture', 'is', 'loaded', 'down', 'with', 'jerkoff', 'gimmicks', '--', 'annoying', 'machine', 'gun', 'editing', ',', 'sloppy', 'dogme-95', 'camerawork', ',', 'unnecessary', 'split-screen', 'graphics', 'and', 'animation', ',', 'etc', '.', 'etc', '.', '<', 'br', '/', '>', '<', 'br', '/', '>', 'in', 'the', 'absence', 'of', 'a', 'compelling', 'story', 'and', 'unique', 'main', 'character', ',', 'the', 'director', '(', 'and', 'i', 'use', 'the', 'term', 'loosely', ')', 'has', 'thrown', 'together', 'a', 'dozen', 'or', 'so', 'techniques', 'from', 'other', 'films', 'and', 'decided', 'to', 'call', 'the', 'resulting', 'mess', 'a', 'movie', ',', 'among', 'these', ':', 'the', 'trendy', ',', 'bleach-bypass', 'look', 'of', '``', 'narc', '``', 'or', '``', 'traffic', '``', 'or', '``', 'minority', 'report', ';', '``', 'the', 'frantic', ',', 'often', 'incomprehensible', ',', 'throw-the-pieces-of-film-in-the-air', 'cutting', 'style', 'of', '``', 'natural', 'born', 'killers', '``', 'or', '``', '28', 'days', 'later', ';', '``', 'the', 'fill-every-moment-of-silence-with', '-', 'an-old-song-to-evoke-the-period', 'soundtrack', 'of', '``', 'goodfellas', '``', 'or', '``', 'blow', ';', '``', 'the', 'groovy', ',', 'retro', 'title', 'sequence', 'of', '``', 'velvet', 'goldmine', '``', 'or', '``', 'autofocus', '``', 'or', '``', 'catch', 'me', 'if', 'you', 'can', '.', '``', 'the', 'list', 'goes', 'on', 'and', 'on', 'and', 'on', '.', 'pathetic', '.', '<', 'br', '/', '>', '<', 'br', '/', '>', 'i', 'wanted', 'to', 'like', 'this', 'movie', '.', 'i', 'had', 'real', 'hopes', 'for', 'it', '.', '``', 'wonderland', 'avenue', '``', 'had', 'been', 'around', 'for', 'years', ';', 'had', 'the', 'context', 'of', 'the', 'murders', 'been', 'emphasized', 'rather', 'than', 'the', 'murders', 'themselves', ',', 'i', 'think', 'it', 'could', 'have', 'worked', '.', 'had', 'the', 'murders', '(', 'and ...

# %% [markdown]
# **Note:** The corpus may be further preprocessed if necessary (e.g. lowercased) or further cleaned. In this case the version of the IMDb corpus that we use was already lowercased.

# %% [markdown]
# Finally, we can train our Word2Vec word embedding model! For more information on training Word2Vec with gensim, you can check [here](https://radimrehurek.com/gensim/models/word2vec.html).

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(gensim_imdb_corpus, vector_size=100, window=5, min_count=3) 
# Size is the number of dimensions of the embeddings we are going to learn
# Window is the size considered for context of a target word
# Min count is the minimum number of times that a word need to occur to be learnt

# %% [markdown]
# **Note:** You can save and load models using `model.save` and `model.load` functions. This enables you to export your models and use them anytime, or to use models training by someone else (i.e. pre-trained models).

# %% [markdown]
# **Exercise (Optional):** Train the same model using [FastText](https://radimrehurek.com/gensim/models/fasttext.html) instead of Word2Vec. FastText is a model similar to Word2Vec but takes also into account character information, which can be useful for noisy text such as the one we find in social media.

# %%
# Train the model using FastText algorithm instead of Word2Vec
model.train(gensim_imdb_corpus, total_examples=len(gensim_imdb_corpus), epochs=10)

# Save the model
model.save("gensim_imdb.model")

# %%
from gensim.models import FastText

model_fasttext = FastText(gensim_imdb_corpus, vector_size=100, window=5, min_count=3)

# %% [markdown]
# ## PLAYING WITH WORD2VEC
#
# ---
#
# Now that our model has been trained, we can check:
#
# i) what the model has learned in general

# %%
#print(model.wv.vocab)

# Store just the words + their trained embeddings.
word_vectors = model.wv

print(model.wv.key_to_index)
# Out:
# {'the': 0, '.': 1, ',': 2, 'and': 3, 'a': 4, 'of': 5, 'to': 6, 'is': 7, '/': 8, '>': 9, '<': 10, 'br': 11, 'it': 12, 'in': 13, 'i': 14, 'this': 15, 'that': 16, '``': 17, "'s": 18, 'was': 19, 'as': 20, 'for': 21, 'with': 22, 'movie': 23, 'but': 24, 'film': 25, ')': 26, '(': 27, 'you': 28, 'on': 29, "n't": 30, 'not': 31, 'are': 32, 'he': 33, 'his': 34, 'have': 35, 'be': 36, 'one': 37, '!': 38, 'all': 39, 'at': 40, 'they': 41, 'by': 42, 'an': 43, 'who': 44, 'from': 45, 'so': 46, 'like': 47, 'there': 48, 'her': 49, 'or': 50, 'just': 51, 'do': 52, 'about': 53, "'": 54, 'has': 55, 'if': 56, 'out': 57, 'what': 58, '?': 59, 'some': 60, 'good': 61, 'more': 62, 'when': 63, 'she': 64, 'very': 65, 'would': 66, 'even': 67, 'my': 68, 'no': 69, 'up': 70, '-': 71, 'time': 72, 'can': 73, 'which': 74, 'only': 75, 'story': 76, 'really': 77, 'had': 78, 'their': 79, 'see': 80, 'were': 81, 'we': 82, 'me': 83, 'did': 84, 'does': 85, ':': 86, '...': 87, 'than': 88, 'well': 89, 'much': 90, 'could': 91, 'been': 92, 'get': 93, 'people': 94, 'will': 95, 'other': 96, 'bad': 97, 'also': 98, 'into': 99, 'because': 100, 'great': 101, 'first': 102, 'how': 103, 'him': 104, 'most': 105, 'its': 106, 'made': 107, 'then': 108, 'them': 109, 'way': 110, 'make': 111, 'too': 112, 'any': 113, 'after': 114, 'movies': 115, 'think': 116, 'characters': 117, '*': 118, 'character': 119, 'watch': 120, 'films': 121, ';': 122, 'two': 123, 'many': 124, 'seen': 125, 'being': 126, 'never': 127, 'acting': 128, 'plot': 129, 'little': 130, 'where': 131, 'best': 132, 'love': 133, 'life': 134, 'show': 135, 'know': 136, 'ever': 137, 'here': 138, 'better': 139, 'your': 140, 'man': 141, 'still': 142, 'over': 143, 'end': 144, 'off': 145, 'these': 146, 'say': 147, 'should': 148, 'scene': 149, 'why': 150, 'while': 151, 'scenes': 152, 'such': 153, "'ve": 154, '--': 155, 'go': 156, 'something': 157, 'through': 158, 'back': 159, "'m": 160, 'those': 161, 'watching': 162, 'real': 163, 'though': 164, 'now': 165, 'thing': 166, 'years': 167, 'actors': 168, 'another': 169, 'before': 170, 'nothing': 171, 'new': 172, 'actually': 173, 'funny': 174, 'work': 175, 'makes': 176, 'find': 177, 'director': 178, 'look': 179, 'old': 180, 'few': 181, 'going': 182, 'same': 183, 'again': 184, 'lot': 185, 'every': 186, 'part': 187, '&': 188, 'cast': 189, 'us': 190, "'re": 191, 'world': 192, 'quite': 193, 'got': 194, 'want': 195, 'things': 196, 'pretty': 197, 'young': 198, 'seems': 199, 'around': 200, 'ca': 201, 'down': 202, 'however': 203, 'fact': 204, 'take': 205, 'enough': 206, 'both': 207, 'may': 208, 'give': 209, 'between': 210, 'horror': 211, 'original': 212, 'big': 213, 'own': 214, 'thought': 215, 'series': 216, 'without': 217, 'right': 218, 'always': 219, 'long': 220, 'times': 221, 'gets': 222, 'come': 223, 'point': 224, 'family': 225, 'saw': 226, 'role': 227, 'almost': 228, 'interesting': 229, 'must': 230, 'action': 231, 'least': 232, 'comedy': 233, 'whole': 234, 'bit': 235, 'music': 236, 'done': 237, 'script': 238, 'guy': 239, 'anything': 240, 'minutes': 241, 'might': 242, 'last': 243, 'since': 244, 'performance': 245, 'far': 246, 'feel': 247, "'ll": 248, 'probably': 249, 'am': 250, 'woman': 251, 'kind': 252, 'away': 253, 'girl': 254, 'yet': 255, 'rather': 256, 'worst': 257, 'sure': 258, 'fun': 259, 'anyone': 260, 'making': 261, 'each': 262, 'played': 263, 'found': 264, 'tv': 265, 'having': 266, 'day': 267, 'although': 268, 'especially': 269, 'our': 270, 'course': 271, 'believe': 272, 'comes': 273, 'trying': 274, 'goes': 275, 'looks': 276, 'hard': 277, 'different': 278, 'place': 279, 'book': 280, 'put': 281, "'d": 282, 'someone': 283, 'money': 284, '10': 285, 'maybe': 286, 'ending': 287, 'actor': 288, 'reason': 289, 'let': 290, 'everything': 291, 'sense': 292, 'once': 293, 'shows': 294, 'true': 295, 'screen': 296, 'set': 297, '2': 298, 'dvd': 299, 'worth': 300, 'looking': 301, 'main': 302, 'job': 303, 'watched': 304, 'together': 305, 'everyone': 306, 'plays': 307, 'three': 308, 'john': 309, 'said': 310, 'la ...

# %%
print(model_fasttext.wv.key_to_index)
# Out:
# {'the': 0, '.': 1, ',': 2, 'and': 3, 'a': 4, 'of': 5, 'to': 6, 'is': 7, '/': 8, '>': 9, '<': 10, 'br': 11, 'it': 12, 'in': 13, 'i': 14, 'this': 15, 'that': 16, '``': 17, "'s": 18, 'was': 19, 'as': 20, 'for': 21, 'with': 22, 'movie': 23, 'but': 24, 'film': 25, ')': 26, '(': 27, 'you': 28, 'on': 29, "n't": 30, 'not': 31, 'are': 32, 'he': 33, 'his': 34, 'have': 35, 'be': 36, 'one': 37, '!': 38, 'all': 39, 'at': 40, 'they': 41, 'by': 42, 'an': 43, 'who': 44, 'from': 45, 'so': 46, 'like': 47, 'there': 48, 'her': 49, 'or': 50, 'just': 51, 'do': 52, 'about': 53, "'": 54, 'has': 55, 'if': 56, 'out': 57, 'what': 58, '?': 59, 'some': 60, 'good': 61, 'more': 62, 'when': 63, 'she': 64, 'very': 65, 'would': 66, 'even': 67, 'my': 68, 'no': 69, 'up': 70, '-': 71, 'time': 72, 'can': 73, 'which': 74, 'only': 75, 'story': 76, 'really': 77, 'had': 78, 'their': 79, 'see': 80, 'were': 81, 'we': 82, 'me': 83, 'did': 84, 'does': 85, ':': 86, '...': 87, 'than': 88, 'well': 89, 'much': 90, 'could': 91, 'been': 92, 'get': 93, 'people': 94, 'will': 95, 'other': 96, 'bad': 97, 'also': 98, 'into': 99, 'because': 100, 'great': 101, 'first': 102, 'how': 103, 'him': 104, 'most': 105, 'its': 106, 'made': 107, 'then': 108, 'them': 109, 'way': 110, 'make': 111, 'too': 112, 'any': 113, 'after': 114, 'movies': 115, 'think': 116, 'characters': 117, '*': 118, 'character': 119, 'watch': 120, 'films': 121, ';': 122, 'two': 123, 'many': 124, 'seen': 125, 'being': 126, 'never': 127, 'acting': 128, 'plot': 129, 'little': 130, 'where': 131, 'best': 132, 'love': 133, 'life': 134, 'show': 135, 'know': 136, 'ever': 137, 'here': 138, 'better': 139, 'your': 140, 'man': 141, 'still': 142, 'over': 143, 'end': 144, 'off': 145, 'these': 146, 'say': 147, 'should': 148, 'scene': 149, 'why': 150, 'while': 151, 'scenes': 152, 'such': 153, "'ve": 154, '--': 155, 'go': 156, 'something': 157, 'through': 158, 'back': 159, "'m": 160, 'those': 161, 'watching': 162, 'real': 163, 'though': 164, 'now': 165, 'thing': 166, 'years': 167, 'actors': 168, 'another': 169, 'before': 170, 'nothing': 171, 'new': 172, 'actually': 173, 'funny': 174, 'work': 175, 'makes': 176, 'find': 177, 'director': 178, 'look': 179, 'old': 180, 'few': 181, 'going': 182, 'same': 183, 'again': 184, 'lot': 185, 'every': 186, 'part': 187, '&': 188, 'cast': 189, 'us': 190, "'re": 191, 'world': 192, 'quite': 193, 'got': 194, 'want': 195, 'things': 196, 'pretty': 197, 'young': 198, 'seems': 199, 'around': 200, 'ca': 201, 'down': 202, 'however': 203, 'fact': 204, 'take': 205, 'enough': 206, 'both': 207, 'may': 208, 'give': 209, 'between': 210, 'horror': 211, 'original': 212, 'big': 213, 'own': 214, 'thought': 215, 'series': 216, 'without': 217, 'right': 218, 'always': 219, 'long': 220, 'times': 221, 'gets': 222, 'come': 223, 'point': 224, 'family': 225, 'saw': 226, 'role': 227, 'almost': 228, 'interesting': 229, 'must': 230, 'action': 231, 'least': 232, 'comedy': 233, 'whole': 234, 'bit': 235, 'music': 236, 'done': 237, 'script': 238, 'guy': 239, 'anything': 240, 'minutes': 241, 'might': 242, 'last': 243, 'since': 244, 'performance': 245, 'far': 246, 'feel': 247, "'ll": 248, 'probably': 249, 'am': 250, 'woman': 251, 'kind': 252, 'away': 253, 'girl': 254, 'yet': 255, 'rather': 256, 'worst': 257, 'sure': 258, 'fun': 259, 'anyone': 260, 'making': 261, 'each': 262, 'played': 263, 'found': 264, 'tv': 265, 'having': 266, 'day': 267, 'although': 268, 'especially': 269, 'our': 270, 'course': 271, 'believe': 272, 'comes': 273, 'trying': 274, 'goes': 275, 'looks': 276, 'hard': 277, 'different': 278, 'place': 279, 'book': 280, 'put': 281, "'d": 282, 'someone': 283, 'money': 284, '10': 285, 'maybe': 286, 'ending': 287, 'actor': 288, 'reason': 289, 'let': 290, 'everything': 291, 'sense': 292, 'once': 293, 'shows': 294, 'true': 295, 'screen': 296, 'set': 297, '2': 298, 'dvd': 299, 'worth': 300, 'looking': 301, 'main': 302, 'job': 303, 'watched': 304, 'together': 305, 'everyone': 306, 'plays': 307, 'three': 308, 'john': 309, 'said': 310, 'la ...

# %% [markdown]
# ii) How many words are there in the word embeddings?

# %%
#print(len(model.wv.vocab))

print(len(model.wv.key_to_index))
# Out:
# 40166

# %%
print(len(model_fasttext.wv.key_to_index))
# Out:
# 40166

# %% [markdown]
#  iii) What is the vector for each word? The size for each embedding vector should have 100 dimensions.

# %%
#vector_movie=model['movie']
vector_movie=model.wv['movie']
print ("Number of dimensions: "+str(len(vector_movie)))
print (vector_movie)
# Out:
# Number of dimensions: 100
# [ 4.7187195   0.6391044   3.2110643  -1.6583861  -3.008352   -0.10702334
#  -3.599195   -0.8350251   0.9289836   2.246731    0.24415356 -0.23169012
#   0.54113257 -2.197405   -1.7457457   4.111549    1.7398655  -4.299542
#   2.320371   -0.15107937 -0.53977436  3.880567   -0.5771787  -1.777853
#  -1.0839218   0.50750846 -0.87219536 -0.24411763  1.2296457   0.870925
#   1.3740119  -0.47693112 -1.475267    1.8540196  -1.446466   -1.1510545
#  -0.17366807 -0.48329112 -1.8186642  -0.72412914 -3.0490034   0.952467
#   2.8459554  -0.48527834 -0.45080146 -4.191804   -0.09094614 -3.2207654
#  -1.4678178   1.2428933   0.38197935  0.2661844   1.0341221   0.6437449
#   0.10011708 -1.3196064  -3.810715   -1.4390714   2.9951015  -2.0260856
#  -2.7983303  -1.0379045   2.3958163   0.21883397 -1.9545356  -0.7884925
#  -0.9001525   0.21452707 -0.08642765 -0.6695173   2.3629045   1.0489724
#  -0.92969394  0.33157843  0.69601643 -1.0386292   2.3327994  -0.82911557
#   0.39917257 -1.5917305   1.2185732   0.03231001 -0.43228102 -2.0767732
#   0.8459062   2.0552557   0.2959302  -0.36555386 -0.32819083  1.2233771
#  -0.7650301   0.7052644  -0.62361103 -0.23391196 -1.053133    1.6574769
#  -1.0254929   1.026301    0.5485284   2.2548466 ]

# %%
vector_movie_fasttext=model_fasttext.wv['movie']
print ("Number of dimensions: "+str(len(vector_movie_fasttext)))
print (vector_movie_fasttext)
# Out:
# Number of dimensions: 100
# [-1.8847263   2.9914157   3.6427753   2.95253    -2.9798703   2.17487
#   1.7798916   1.444022   -1.0086968   0.13797578 -0.19609445  0.7219611
#  -1.6022784   0.66163754  1.2486875   0.50136536 -0.27980998 -1.7431422
#   0.14650533 -2.580268   -0.6733206   2.4943695   0.61561674  0.26509908
#  -0.8795058   4.7205505   0.94685054 -1.4943553  -1.0044161   2.5462122
#  -0.7904467  -0.8588277  -2.3303368   0.51841575 -0.6424538  -4.088907
#   1.4003118   0.6907385   0.39785296  1.939632   -0.774195    0.86340433
#   0.33619282 -2.3723967   0.96883714  0.43044004  3.6778953  -1.1703097
#   0.52817243 -2.0437567   1.4481575  -1.3879666  -2.9637227  -1.4382756
#  -4.6750665   4.5933294  -0.17462079  1.0467371  -0.2919     -2.2890854
#   1.0100875  -1.9243292   0.7238644   1.0158615  -0.5447782   0.1260048
#   0.15355998 -0.36525223  2.3095224   0.6608069  -2.5905771  -0.86844903
#   1.0944118   0.980903   -0.5229587   1.5734702  -3.0814142   4.359117
#   0.6371427   1.7751839   0.37180665  1.6894244   0.12643903 -1.232832
#   2.4870634  -1.1637849  -1.7840596  -0.924147    0.77996564 -1.0798565
#   2.689664   -3.4851751  -2.3807886  -1.0645574  -0.32003197 -0.78793335
#   0.7647291  -1.4406499  -1.1854424   0.14823167]

# %% [markdown]
# In addition, we can check the vocabulary learned with:

# %%
#print(model.wv.vocab.keys())

print(model.wv.key_to_index.keys())
# Out:
# dict_keys(['the', '.', ',', 'and', 'a', 'of', 'to', 'is', '/', '>', '<', 'br', 'it', 'in', 'i', 'this', 'that', '``', "'s", 'was', 'as', 'for', 'with', 'movie', 'but', 'film', ')', '(', 'you', 'on', "n't", 'not', 'are', 'he', 'his', 'have', 'be', 'one', '!', 'all', 'at', 'they', 'by', 'an', 'who', 'from', 'so', 'like', 'there', 'her', 'or', 'just', 'do', 'about', "'", 'has', 'if', 'out', 'what', '?', 'some', 'good', 'more', 'when', 'she', 'very', 'would', 'even', 'my', 'no', 'up', '-', 'time', 'can', 'which', 'only', 'story', 'really', 'had', 'their', 'see', 'were', 'we', 'me', 'did', 'does', ':', '...', 'than', 'well', 'much', 'could', 'been', 'get', 'people', 'will', 'other', 'bad', 'also', 'into', 'because', 'great', 'first', 'how', 'him', 'most', 'its', 'made', 'then', 'them', 'way', 'make', 'too', 'any', 'after', 'movies', 'think', 'characters', '*', 'character', 'watch', 'films', ';', 'two', 'many', 'seen', 'being', 'never', 'acting', 'plot', 'little', 'where', 'best', 'love', 'life', 'show', 'know', 'ever', 'here', 'better', 'your', 'man', 'still', 'over', 'end', 'off', 'these', 'say', 'should', 'scene', 'why', 'while', 'scenes', 'such', "'ve", '--', 'go', 'something', 'through', 'back', "'m", 'those', 'watching', 'real', 'though', 'now', 'thing', 'years', 'actors', 'another', 'before', 'nothing', 'new', 'actually', 'funny', 'work', 'makes', 'find', 'director', 'look', 'old', 'few', 'going', 'same', 'again', 'lot', 'every', 'part', '&', 'cast', 'us', "'re", 'world', 'quite', 'got', 'want', 'things', 'pretty', 'young', 'seems', 'around', 'ca', 'down', 'however', 'fact', 'take', 'enough', 'both', 'may', 'give', 'between', 'horror', 'original', 'big', 'own', 'thought', 'series', 'without', 'right', 'always', 'long', 'times', 'gets', 'come', 'point', 'family', 'saw', 'role', 'almost', 'interesting', 'must', 'action', 'least', 'comedy', 'whole', 'bit', 'music', 'done', 'script', 'guy', 'anything', 'minutes', 'might', 'last', 'since', 'performance', 'far', 'feel', "'ll", 'probably', 'am', 'woman', 'kind', 'away', 'girl', 'yet', 'rather', 'worst', 'sure', 'fun', 'anyone', 'making', 'each', 'played', 'found', 'tv', 'having', 'day', 'although', 'especially', 'our', 'course', 'believe', 'comes', 'trying', 'goes', 'looks', 'hard', 'different', 'place', 'book', 'put', "'d", 'someone', 'money', '10', 'maybe', 'ending', 'actor', 'reason', 'let', 'everything', 'sense', 'once', 'shows', 'true', 'screen', 'set', '2', 'dvd', 'worth', 'looking', 'main', 'job', 'watched', 'together', 'everyone', 'plays', 'three', 'john', 'said', 'later', 'instead', 'audience', 'play', 'seem', 'takes', 'beautiful', 'effects', 'himself', 'version', 'during', 'left', 'night', 'seeing', 'house', 'special', 'excellent', 'wife', 'american', 'idea', 'father', 'else', 'nice', 'shot', 'simply', 'year', 'read', 'black', 'high', 'less', 'star', 'war', 'help', 'completely', 'fan', 'poor', 'second', 'death', 'hollywood', 'men', 'either', 'used', 'mind', 'given', 'home', 'kids', 'need', 'try', 'enjoy', 'performances', 'classic', 'women', 'short', 'wrong', 'rest', 'boring', 'use', 'until', 'friends', 'along', 'dead', 'truly', 'half', 'production', 'line', 'tell', 'couple', 'remember', 'next', 'start', 'perhaps', 'stupid', 'came', 'recommend', 'awful', 'moments', 'episode', 'mean', 'wonderful', 'understand', 'full', 'terrible', 'camera', 'getting', 'stars', 'playing', 'keep', 'doing', 'others', 'sex', 'often', 'video', 'small', 'definitely', 'gives', 'early', 'person', 'school', 'face', 'perfect', 'itself', 'name', 'become', 'human', 'finally', 'lines', 'yes', 'lost', 'felt', 'dialogue', 'case', 'piece', 'supposed', 'liked', 'top', 'children', 'absolutely', 'head', 'budget', 'title', 'live', 'mother', 'written', 'boy', 'against', 'picture', 'style', 'cinema', 'sort', 'entire', 'certainly', 'went', 'worse', 'waste', 'problem', 'hope', 'entertaining', 'evil', 'overall', 'killer', '3', 'several', 'friend', 'loved', 'fans', 'beginning', '1', 'oh', 'lives', 'white', 'becomes', ...

# %%
print(model_fasttext.wv.key_to_index.keys())
# Out:
# dict_keys(['the', '.', ',', 'and', 'a', 'of', 'to', 'is', '/', '>', '<', 'br', 'it', 'in', 'i', 'this', 'that', '``', "'s", 'was', 'as', 'for', 'with', 'movie', 'but', 'film', ')', '(', 'you', 'on', "n't", 'not', 'are', 'he', 'his', 'have', 'be', 'one', '!', 'all', 'at', 'they', 'by', 'an', 'who', 'from', 'so', 'like', 'there', 'her', 'or', 'just', 'do', 'about', "'", 'has', 'if', 'out', 'what', '?', 'some', 'good', 'more', 'when', 'she', 'very', 'would', 'even', 'my', 'no', 'up', '-', 'time', 'can', 'which', 'only', 'story', 'really', 'had', 'their', 'see', 'were', 'we', 'me', 'did', 'does', ':', '...', 'than', 'well', 'much', 'could', 'been', 'get', 'people', 'will', 'other', 'bad', 'also', 'into', 'because', 'great', 'first', 'how', 'him', 'most', 'its', 'made', 'then', 'them', 'way', 'make', 'too', 'any', 'after', 'movies', 'think', 'characters', '*', 'character', 'watch', 'films', ';', 'two', 'many', 'seen', 'being', 'never', 'acting', 'plot', 'little', 'where', 'best', 'love', 'life', 'show', 'know', 'ever', 'here', 'better', 'your', 'man', 'still', 'over', 'end', 'off', 'these', 'say', 'should', 'scene', 'why', 'while', 'scenes', 'such', "'ve", '--', 'go', 'something', 'through', 'back', "'m", 'those', 'watching', 'real', 'though', 'now', 'thing', 'years', 'actors', 'another', 'before', 'nothing', 'new', 'actually', 'funny', 'work', 'makes', 'find', 'director', 'look', 'old', 'few', 'going', 'same', 'again', 'lot', 'every', 'part', '&', 'cast', 'us', "'re", 'world', 'quite', 'got', 'want', 'things', 'pretty', 'young', 'seems', 'around', 'ca', 'down', 'however', 'fact', 'take', 'enough', 'both', 'may', 'give', 'between', 'horror', 'original', 'big', 'own', 'thought', 'series', 'without', 'right', 'always', 'long', 'times', 'gets', 'come', 'point', 'family', 'saw', 'role', 'almost', 'interesting', 'must', 'action', 'least', 'comedy', 'whole', 'bit', 'music', 'done', 'script', 'guy', 'anything', 'minutes', 'might', 'last', 'since', 'performance', 'far', 'feel', "'ll", 'probably', 'am', 'woman', 'kind', 'away', 'girl', 'yet', 'rather', 'worst', 'sure', 'fun', 'anyone', 'making', 'each', 'played', 'found', 'tv', 'having', 'day', 'although', 'especially', 'our', 'course', 'believe', 'comes', 'trying', 'goes', 'looks', 'hard', 'different', 'place', 'book', 'put', "'d", 'someone', 'money', '10', 'maybe', 'ending', 'actor', 'reason', 'let', 'everything', 'sense', 'once', 'shows', 'true', 'screen', 'set', '2', 'dvd', 'worth', 'looking', 'main', 'job', 'watched', 'together', 'everyone', 'plays', 'three', 'john', 'said', 'later', 'instead', 'audience', 'play', 'seem', 'takes', 'beautiful', 'effects', 'himself', 'version', 'during', 'left', 'night', 'seeing', 'house', 'special', 'excellent', 'wife', 'american', 'idea', 'father', 'else', 'nice', 'shot', 'simply', 'year', 'read', 'black', 'high', 'less', 'star', 'war', 'help', 'completely', 'fan', 'poor', 'second', 'death', 'hollywood', 'men', 'either', 'used', 'mind', 'given', 'home', 'kids', 'need', 'try', 'enjoy', 'performances', 'classic', 'women', 'short', 'wrong', 'rest', 'boring', 'use', 'until', 'friends', 'along', 'dead', 'truly', 'half', 'production', 'line', 'tell', 'couple', 'remember', 'next', 'start', 'perhaps', 'stupid', 'came', 'recommend', 'awful', 'moments', 'episode', 'mean', 'wonderful', 'understand', 'full', 'terrible', 'camera', 'getting', 'stars', 'playing', 'keep', 'doing', 'others', 'sex', 'often', 'video', 'small', 'definitely', 'gives', 'early', 'person', 'school', 'face', 'perfect', 'itself', 'name', 'become', 'human', 'finally', 'lines', 'yes', 'lost', 'felt', 'dialogue', 'case', 'piece', 'supposed', 'liked', 'top', 'children', 'absolutely', 'head', 'budget', 'title', 'live', 'mother', 'written', 'boy', 'against', 'picture', 'style', 'cinema', 'sort', 'entire', 'certainly', 'went', 'worse', 'waste', 'problem', 'hope', 'entertaining', 'evil', 'overall', 'killer', '3', 'several', 'friend', 'loved', 'fans', 'beginning', '1', 'oh', 'lives', 'white', 'becomes', ...

# %% [markdown]
# Or

# %%
#for word in list(model.wv.vocab.keys())[:5]:
  #print(word)

for word in list(model.wv.key_to_index.keys())[:5]:
  print(word)
# Out:
# the
# .
# ,
# and
# a

# %% [markdown]
# We can also check the similarity (measured by cosine similarity) between some words. Let's start with finding the most similar words to *film* or *casablanca* in our vector space. We can find the most similar words of any input word by using the `.most_similar` command.

# %%
#model.most_similar('movie')

model.wv.most_similar('movie')
# Out:
# [('film', 0.9432273507118225),
#  ('flick', 0.7656893730163574),
#  ('show', 0.6861786246299744),
#  ('documentary', 0.6572632193565369),
#  ('picture', 0.6507958769798279),
#  ('it', 0.6313016414642334),
#  ('sequel', 0.6287752985954285),
#  ('episode', 0.6088770031929016),
#  ('movies', 0.595389723777771),
#  ('mess', 0.5896077156066895)]

# %%
model_fasttext.wv.most_similar('movie')
# Out:
# [('a-movie', 0.9727110266685486),
#  ('d-movie', 0.9726241827011108),
#  ('c-movie', 0.9724273681640625),
#  ('movie.i', 0.9628679156303406),
#  ('movie.in', 0.9618176221847534),
#  ('movie.it', 0.9592311382293701),
#  ('tv-movie', 0.9555339217185974),
#  ('film', 0.950377881526947),
#  ('b-movie', 0.9382290244102478),
#  ('moovie', 0.9381521940231323)]

# %%
#model.most_similar('casablanca')

model.wv.most_similar('casablanca')
# Out:
# [('smokey', 0.7568488717079163),
#  ('dallas', 0.7456918358802795),
#  ('anchorman', 0.7387089133262634),
#  ('re-animator', 0.7242797017097473),
#  ('rouge', 0.7228572368621826),
#  ('magnolias', 0.7136237025260925),
#  ('goodfellas', 0.7131175398826599),
#  ('bueller', 0.7123828530311584),
#  ('strada', 0.712144136428833),
#  ('michaels', 0.71092689037323)]

# %%
model_fasttext.wv.most_similar('casablanca')
# Out:
# [('casa', 0.889998197555542),
#  ('cadillac', 0.8795784711837769),
#  ('cairo', 0.8738831281661987),
#  ('casanova', 0.8594125509262085),
#  ('casinos', 0.8516393899917603),
#  ('cassi', 0.8495320677757263),
#  ('blanca', 0.8494088649749756),
#  ('cazalÃ©', 0.8493580222129822),
#  ('caesar', 0.8486674427986145),
#  ('cagey', 0.84819495677948)]

# %% [markdown]
# We can also check the similarity between two given words.

# %%
#print(model.similarity('movie', 'film'))
print(model.wv.similarity('movie', 'film'))
#print(model.similarity('movie', 'popcorn'))
print(model.wv.similarity('movie', 'popcorn'))
#print(model.similarity('movie', 'table'))
print(model.wv.similarity('movie', 'table'))
# Out:
# 0.9432273
# 0.22088306
# -0.014616387

# %%
print(model.wv.similarity('movie', 'a-movie'))
# Out:
# 0.048673112

# %% [markdown]
# Here we can see how words like *movie* and *film* are very close (in fact they are synonyms). Then other words like *movie* and *popcorn* are somehow related, while *movie* and *table* do not seem to be similar at all in this corpus.

# %% [markdown]
# **Note:** In this notebook we have learned our own word embeddings in IMDb. However, please note that in many cases we are going to directly use an available pre-trained word embedding model. These are generally trained on large corpora and are therefore more complete/accurate. For example, there are pre-trained models for [Word2Vec](https://code.google.com/archive/p/word2vec/), [GloVe](https://nlp.stanford.edu/projects/glove/) or even [FastText trained on Twitter](https://github.com/pedrada88/crossembeddings-twitter).

# %% [markdown]
# **Exercise (optional):** Choose a pre-trained model from Word2Vec, GloVe or FastText (there are many available online) and load it using gensim. Check a few similarities and compare it with the word embeddings trained on IMDb.

# %% [markdown]
# **Exercise 1:** Train a Word2Vec word embedding model on the IMDb corpus with 75 dimensions and a window size of 8. Then, check the most similar words of *movie* in the vector space and the similarity between *movie* and *table*. Compare the results with the previous trained model.

# %%
# Train with 75 dimensions and window f 8
model2 = Word2Vec(gensim_imdb_corpus, vector_size=75, window=8, min_count=3)

# %%
# Check the most similar words to movie
model2.wv.most_similar('movie')
# Out:
# [('film', 0.9196907877922058),
#  ('flick', 0.7433812022209167),
#  ('picture', 0.6529372930526733),
#  ('documentary', 0.6407851576805115),
#  ('show', 0.6344099044799805),
#  ('it', 0.617644727230072),
#  ('movies', 0.6010158061981201),
#  ('thing', 0.5990554094314575),
#  ('mess', 0.5964698791503906),
#  ('turkey', 0.5867173075675964)]

# %%
# Check similarity between movie and table
print(model2.wv.similarity('movie', 'table'))
# Out:
# -0.054146286

# %%
print(model2.wv.similarity('movie', 'a-movie'))
# Out:
# 0.100233175

# %% [markdown]
# **Exercise (optional):** Take a corpus of your choice (e.g. from one of the NLP projects) and train a word embedding model using gensim. Check a few similarities of words and compare with the models trained on IMDb.

# %%
# Download a corpus of movie reviews
nltk.download('movie_reviews')

from nltk.corpus import movie_reviews

# Get all the words in the corpus
all_words = movie_reviews.words()
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\c21099797\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\movie_reviews.zip.

# %%
# Visualize the first 100 words
print(all_words[:100])
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...]

# %%
print(len(all_words))
# Out:
# 1583820

# %%
# Get the frequency distribution of all words
all_words_freq = nltk.FreqDist(all_words)

# %%
print(all_words_freq.most_common(10))
# Out:
# [(',', 77717), ('the', 76529), ('.', 65876), ('a', 38106), ('and', 35576), ('of', 34123), ('to', 31937), ("'", 30585), ('is', 25195), ('in', 21822)]

# %%
# Train the model with the corpus of movie reviews
model3 = Word2Vec(movie_reviews.sents(), vector_size=100, window=5, min_count=3)

# %%
# Compare the most similar words to movie
model3.wv.most_similar('movie')
# Out:
# [('film', 0.9465670585632324),
#  ('picture', 0.8432642221450806),
#  ('sequel', 0.7543413639068604),
#  ('case', 0.6854908466339111),
#  ('ending', 0.6776500344276428),
#  ('premise', 0.677554190158844),
#  ('story', 0.6584279537200928),
#  ('comedy', 0.6540756225585938),
#  ('thing', 0.653117299079895),
#  ('plot', 0.6506665945053101)]

# %%
# Compare the most similar words to film
model3.wv.most_similar('film')
# Out:
# [('movie', 0.9465671181678772),
#  ('picture', 0.8319717049598694),
#  ('premise', 0.7189927697181702),
#  ('sequel', 0.7023196816444397),
#  ('case', 0.6926998496055603),
#  ('ending', 0.6790832281112671),
#  ('story', 0.6710167527198792),
#  ('plot', 0.668138861656189),
#  ('script', 0.6632994413375854),
#  ('installment', 0.6486179828643799)]

# %%
# Compare the two models trained with the IMDB corpus and the movie reviews corpus
print(model.wv.similarity('movie', 'film'))
print(model3.wv.similarity('movie', 'film'))

# Compare the two models trained with the IMDB corpus and the movie reviews corpus
print(model.wv.similarity('movie', 'popcorn'))
print(model3.wv.similarity('movie', 'popcorn'))
# Out:
# 0.94246566
# 0.946567
# 0.13621056
# 0.27083156
